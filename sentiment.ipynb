# %% [markdown]
# Question: Can deep learning NLP methods distinguish low-stress (1) from higher stress (2-5) in individuals during retelling of autobiographical memories of an emotional event.
#
# Hypothesis: We hypothesize that deep-learning based NLP methods applied to autobiographical memory text can distinguish between stressful state during memory recollection.

# %% [markdown]
# Features: Text itself

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv("https://raw.githubusercontent.com/HamidAbuwarda/NMA_DL_SentimentAnalysis/main/Hippocorpus_data/hippoCorpusV2.csv")
data=data[["AssignmentId", "stressful", "memType", "story", "timeSinceEvent"]]
data.head()
threshold = 1

mem_types = data['memType'].unique()

#need to decide if we're binarizing values/what are we classifying.

# %% [markdown]
# ## Freq plots

# %%
n_types = len(mem_types)
plt, axes = plt.subplots(1,3, figsize=(15,4))

for i, mem_type in enumerate(mem_types):
    subset = data[data['memType'] == mem_type]

    axes[i].hist(subset['stressful'], bins=np.arange(0.5, 6.5, 1),
                 alpha=0.7, edgecolor='black')
    axes[i].set_title(f'{mem_type}\n(n={len(subset)})')
    axes[i].set_xlabel('stress level')
    axes[i].set_ylabel('number')
    axes[i].grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# Binary bins

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
threshold = 1
data['stress_binary'] = data['stressful'].apply(lambda x: '0' if x <= threshold else '1')

plt, axes = plt.subplots(1,3, figsize=(15,4))

for i, mem_type in enumerate(mem_types):
    subset = data[data['memType'] == mem_type]
    counts = subset['stress_binary'].value_counts()
    categories = ['0', '1']
    values = [counts.get('0', 0), counts.get('1', 0)]

    axes[i].bar(categories, values, alpha=0.7, edgecolor='black')
    axes[i].set_title(f'{mem_type}\n(n={len(subset)})')
    axes[i].set_xlabel('stress')
    axes[i].set_ylabel('number')
    axes[i].grid(True, alpha=0.3)

plt.show()
