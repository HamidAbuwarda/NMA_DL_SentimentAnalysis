# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("https://raw.githubusercontent.com/HamidAbuwarda/NMA_DL_SentimentAnalysis/main/Hippocorpus_data/hippoCorpusV2.csv")
data=data[["AssignmentId", "stressful", "memType", "story", "timeSinceEvent"]]
data.head()

#need to decide if we're binarizing values/what are we classifying.
# Out:
#                      AssignmentId  stressful   memType  \
# 0  32RIADZISTQWI5XIVG5BN0VMYFRS4U        1.0  imagined
# 1  3018Q3ZVOJCZJFDMPSFXATCQ4DARA2        1.0  recalled
# 2  3IRIK4HM3B6UQBC0HI8Q5TBJZLEC61        1.0  imagined
# 3  3018Q3ZVOJCZJFDMPSFXATCQG04RAI        2.0  recalled
# 4  3MTMREQS4W44RBU8OMP3XSK8NMJAWZ        4.0  imagined
#
#                                                story  timeSinceEvent
# 0  Concerts are my most favorite thing, and my bo...            90.0
# 1  The day started perfectly, with a great drive ...            90.0
# 2  It seems just like yesterday but today makes f...           150.0
# 3  Five months ago, my niece and nephew were born...           150.0
# 4  About a month ago I went to burning man. I was...            30.0
